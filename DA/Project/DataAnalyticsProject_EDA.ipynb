# %%
#include all the libraries to be imported here 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
train = pd.read_csv(r"C:\Users\tejas\Desktop\TDAWG\Tejas' stuff\College\Sem5\DA\Project and Worksheets\Project\Project_Dataset\train.csv")
test = pd.read_csv(r"C:\Users\tejas\Desktop\TDAWG\Tejas' stuff\College\Sem5\DA\Project and Worksheets\Project\Project_Dataset\test.csv")

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
train.shape
# Out:
# (7352, 563)

# %%
test.shape
# Out:
# (2947, 563)

# %%
#Checking for null values and data cleaning 
train.isnull().any()
# Out:
# tBodyAcc-mean()-X       False
# tBodyAcc-mean()-Y       False
# tBodyAcc-mean()-Z       False
# tBodyAcc-std()-X        False
# tBodyAcc-std()-Y        False
#                         ...
# angle(X,gravityMean)    False
# angle(Y,gravityMean)    False
# angle(Z,gravityMean)    False
# subject                 False
# Activity                False
# Length: 563, dtype: bool

# %%
test.isnull().any()
# Out:
# tBodyAcc-mean()-X       False
# tBodyAcc-mean()-Y       False
# tBodyAcc-mean()-Z       False
# tBodyAcc-std()-X        False
# tBodyAcc-std()-Y        False
#                         ...
# angle(X,gravityMean)    False
# angle(Y,gravityMean)    False
# angle(Z,gravityMean)    False
# subject                 False
# Activity                False
# Length: 563, dtype: bool

# %%
#Checking for duplicate values 
print(sum(train.duplicated()))
print(sum(test.duplicated()))
# Out:
# 0
# 0

# %%
#Columns to be dropped if any

# %%
train.dtypes.value_counts()
# Out:
# float64    561
# int64        1
# object       1
# dtype: int64

# %%
test.dtypes.value_counts()
# Out:
# float64    561
# int64        1
# object       1
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train.columns.values
# Out:
# array(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z',
#        'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z',
#        'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y',
#        'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y',
#        'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y',
#        'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1',
#        'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3',
#        'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1',
#        'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3',
#        'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1',
#        'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3',
#        'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y',
# ...

# %%
test.columns.values
# Out:
# array(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z',
#        'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z',
#        'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y',
#        'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y',
#        'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y',
#        'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1',
#        'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3',
#        'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1',
#        'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3',
#        'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1',
#        'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3',
#        'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y',
# ...

# %%
train['Activity'].value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
#counts of all the columns in descending/ascending order

# %%
#The actual EDA 

#Barplot of all activities

# %%
#How long does the participant actually use the staircase?

# %%
#Some density plot to distinguish between static and dynamic activities

# %%
#Box plot of tAccMag across various activities

# %%
#PCA

# %%
#Checking Correlation between features

# %%
#Angle between Y axis and gravity

# %%
#T-SNE

# %%
#Feature selection here

# %%
#Confusion matrix

# %%
#Different classifiers

# %%
#Other ML models (NNs, HMMs etc ?)

# %%
pd.crosstab(train.subject, train.Activity, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col2 {
#             background-color:  #fffe00;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col3 {
#             background-color:  #fff500;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col4 {
#             background-color:  #fffc00;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col5 {
#             background-color:  #fffc00;
#             color:  #000000;
#         }    #T_7743e1a7_1752_11eb_9a68_040e3cc6b658row0_col6 {
#             background-color:  #fffd00;
#             color:  #000000;
# ...

# %%
X_train=train.iloc[:,:-2]
y_train=train.iloc[:,-1]

X_test=test.iloc[:,:-2]
y_test=test.iloc[:,-1]

# %%
#Scaling the features 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#encoding the labels (y)

from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

y_train=encoder.fit_transform(y_train)
y_train=pd.get_dummies(y_train).values


y_test=encoder.fit_transform(y_test)
y_test=pd.get_dummies(y_test).values

# %%
#Some weird attempt at explained variance using PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=None)
X_train=pca.fit_transform(X_train)
X_test=pca.transform(X_test)
explained_variance=pca.explained_variance_ratio_

print(explained_variance)
# Out:
# [5.07811723e-01 6.58068027e-02 2.80643677e-02 2.50395275e-02
#  1.88828501e-02 1.72400642e-02 1.37101147e-02 1.19907768e-02
#  9.95859511e-03 9.65086590e-03 8.60051649e-03 8.00280950e-03
#  7.63996369e-03 6.45328924e-03 6.32324346e-03 5.99722090e-03
#  5.86750302e-03 5.75407392e-03 5.67921047e-03 5.27295779e-03
#  5.00362925e-03 4.88408406e-03 4.78205784e-03 4.68562930e-03
#  4.49289260e-03 4.21027243e-03 4.17978682e-03 4.05570369e-03
#  3.88524168e-03 3.87018044e-03 3.65958878e-03 3.54553381e-03
#  3.47942606e-03 3.37187109e-03 3.29676999e-03 3.28215050e-03
#  3.20529478e-03 2.95614939e-03 2.86722415e-03 2.85074548e-03
#  2.68766324e-03 2.65619859e-03 2.63405989e-03 2.58850596e-03
#  2.49054872e-03 2.46954034e-03 2.40679913e-03 2.36115075e-03
#  2.30278857e-03 2.27567245e-03 2.20164699e-03 2.13466984e-03
#  2.07704456e-03 2.02496620e-03 1.99779441e-03 1.97750625e-03
#  1.94273627e-03 1.90237160e-03 1.88064891e-03 1.86215970e-03
# ...

# %%
#Shape of features 
print(X_train.shape , y_train.shape)
print(X_test.shape , y_test.shape)
# Out:
# (7352, 561) (7352, 6)
# (2947, 561) (2947, 6)

# %%
# !pip install tensorflow
# !pip install keras 
import keras

# %%
#Callbacks and checkpointing 
filepath="HAR_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
#making the necesssary imports 
from sklearn.model_selection import train_test_split
from keras.models import Sequential 
from keras.layers import Dense,Dropout,BatchNormalization
from keras.utils import np_utils
from keras.optimizers import Adam #Can try with other optimizers like RMSprop and others

# %%
#definition of the model - tweak the layers 
model = Sequential()

#Add layers
model.add(Dense(units=64,kernel_initializer='uniform',activation='relu',input_dim=X_train.shape[1]))

#Can try to add BatchNormalization here to improve accuracy 
model.add(BatchNormalization())
model.add(Dense(units=128,kernel_initializer='uniform',activation='relu'))

model.add(Dense(units=64,kernel_initializer='uniform',activation='relu'))

model.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))

model.add(Dense(units=6,kernel_initializer='uniform',activation='softmax')) #Using softmax instead of sigmoid

# %%
#Compile the model and get the summary 
model.compile(optimizer = 'adam',loss = 'categorical_crossentropy',metrics = ['accuracy'])  #Can explicitly set learning rate and tweak it to see change in results 

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 64)                35968
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 198
# ...
# Total params: 55,078
# Trainable params: 54,950
# Non-trainable params: 128
# ...

# %%
#try tweaking the batch size and the number of epochs to check for best results 
history = model.fit(X_train, y_train , epochs=50 , batch_size = 256 , validation_data=(X_test, y_test) , callbacks=[checkpoint,lr_reduce])
# Out:
# Epoch 1/50
#  1/29 [>.............................] - ETA: 0s - loss: 2.6207e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 29/29 [==============================] - 0s 3ms/step - loss: 8.0139e-04 - accuracy: 0.9999 - val_loss: 0.2858 - val_accuracy: 0.9454
# Epoch 2/50
#  1/29 [>.............................] - ETA: 0s - loss: 7.7421e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 29/29 [==============================] - 0s 2ms/step - loss: 5.0853e-04 - accuracy: 0.9999 - val_loss: 0.2887 - val_accuracy: 0.9464
# Epoch 3/50
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 4
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Confusion matrix as a Metric 
from sklearn.metrics import confusion_matrix
model.load_weights("HAR_weights.hdf5")
pred = model.predict(X_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(10, 5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-1a06b3a4afba> in <module>
#       1 #Confusion matrix as a Metric
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 model.load_weights("HAR_weights.hdf5")
#       4 pred = model.predict(X_test)
#       5 pred = np.argmax(pred,axis = 1)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2202           'first, then load the weights.')
#    2203     self._assert_weights_created()
# -> 2204     with h5py.File(filepath, 'r') as f:
#    2205       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2206         f = f['model_weights']
#
# ...

# %%
y_pred = model.predict(X_test)

y_pred_class = np.argmax(y_pred,axis=1)

y_test_class = np.argmax(y_test,axis=1)

# %%
y_test_class
# Out:
# array([2, 2, 2, ..., 5, 5, 5], dtype=int64)

# %%
y_pred_class
# Out:
# array([2, 2, 2, ..., 5, 5, 5], dtype=int64)

# %%
#Performance metrics
from sklearn.metrics import classification_report,accuracy_score 
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-5ae822fc1f00> in <module>
#       1 #Performance metrics
#       2 from sklearn.metrics import classification_report,accuracy_score
# ----> 3 print(classification_report(y_test,y_pred))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1927     """
#    1928
# -> 1929     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1930
#    1931     labels_given = True
#
# ...

# %%
#Can export these predictions to another csv file as well
